# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')

from scipy.stats import gaussian_kde
from scipy.optimize import curve_fit, brute, fmin

np.random.seed(0)
xs = np.concatenate([np.random.randn(60) + 8, 3*np.random.randn(100), 5*np.random.randn(40)+8])

order = xs.argsort()

kfunc = gaussian_kde(xs)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 4), tight_layout=True)

ax1.plot(xs)

ax2.plot(xs[order], kfunc(xs[order]), '')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
def opt_brute(idx):
    
    idx = np.unique(idx)
    

    print(idx)
    ix, = np.where(np.diff((np.concatenate([[0], idx]))) < chunk )  
    

        
    idx[ix-1] = -1
    
    ix, = np.where((idx+chunk > arrlen))
    
    idx[ix] = -1
    
    idx = idx[idx!=-1]    
    index = zip(np.concatenate([[0], idx]), np.concatenate([idx, [arrlen]]))
    

        
    return list(index)


import scipy.spatial.distance as spdist

    
chunk = 3
arrlen = 25

idx = np.array([8, 3, 3, 6,10, 30])


opt_brute(idx)
# Out:
# [ 3  6  8 10 30]
# [(0, 3), (3, 10), (10, 25)]
